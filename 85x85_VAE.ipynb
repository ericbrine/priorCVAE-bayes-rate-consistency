# %%
# !ssh-keygen -t rsa -b 4096
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa):
# Created directory '/root/.ssh'.
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /root/.ssh/id_rsa
# Your public key has been saved in /root/.ssh/id_rsa.pub
# The key fingerprint is:
# SHA256:FXI0JQ3gFDyU0rqmG7387xZmS/Ec3DLzio0qZMJspF4 root@313767174d5a
# The key's randomart image is:
# +---[RSA 4096]----+
# |       +*=B+.    |
# |      .o=o +.    |
# |       o.... .   |
# |    . .  .. * .  |
# |   =   .S  + *   |
# |  . E.=   = o .  |
# | . o.*.  + * .   |
# |  . .o..  = o    |
# |    ..ooo=o      |
# +----[SHA256]-----+

# %%
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# Out:
# # github.com:22 SSH-2.0-babeld-9ff4dbf2

# %%
# !cat /root/.ssh/id_rsa.pub
# Out:
# ssh-rsa ... root@313767174d5a

# %%
# !ssh -T git@github.com
# Out:
# Hi Soccolo! You've successfully authenticated, but GitHub does not provide shell access.

# %%
# !git clone git@github.com:elizavetasemenova/PriorCVAE_JAX.git
# Out:
# Cloning into 'PriorCVAE_JAX'...
# remote: Enumerating objects: 1007, done.
# remote: Counting objects: 100% (188/188), done.
# remote: Compressing objects: 100% (108/108), done.
# remote: Total 1007 (delta 100), reused 127 (delta 77), pack-reused 819
# Receiving objects: 100% (1007/1007), 11.85 MiB | 26.85 MiB/s, done.
# Resolving deltas: 100% (465/465), done.

# %%
# !pip install -r requirements.txt
# Out:
# Collecting jax==0.4.13 (from -r requirements.txt (line 1))
#   Downloading jax-0.4.13.tar.gz (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting jaxlib==0.4.13 (from -r requirements.txt (line 2))
#   Downloading jaxlib-0.4.13-cp310-cp310-manylinux2014_x86_64.whl (71.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 MB 12.2 MB/s eta 0:00:00
# Collecting numpyro==0.12.1 (from -r requirements.txt (line 3))
#   Downloading numpyro-0.12.1-py3-none-any.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.6/304.6 kB 23.8 MB/s eta 0:00:00
# Collecting flax==0.6.11 (from -r requirements.txt (line 4))
#   Downloading flax-0.6.11-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.2/227.2 kB 25.6 MB/s eta 0:00:00
# Collecting optax==0.1.5 (from -r requirements.txt (line 5))
#   Downloading optax-0.1.5-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.6/164.6 kB 20.9 MB/s eta 0:00:00
# Requirement already satisfied: torch==2.0.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 6)) (2.0.1+cu118)
# Collecting jupyter==1.0.0 (from -r requirements.txt (line 7))
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: matplotlib==3.7.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 8)) (3.7.1)
# Collecting orbax-checkpoint==0.2.7 (from -r requirements.txt (line 9))
#   Downloading orbax_checkpoint-0.2.7-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.3/91.3 kB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: geopandas==0.13.2 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 10)) (0.13.2)
# Collecting numpy==1.25.1 (from -r requirements.txt (line 11))
#   Downloading numpy-1.25.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 66.4 MB/s eta 0:00:00
# Collecting dill==0.3.6 (from -r requirements.txt (line 12))
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 12.4 MB/s eta 0:00:00
# Collecting arviz==0.16.1 (from -r requirements.txt (line 13))
#   Downloading arviz-0.16.1-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 85.7 MB/s eta 0:00:00
# Requirement already satisfied: ml-dtypes>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jax==0.4.13->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax==0.4.13->-r requirements.txt (line 1)) (3.3.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax==0.4.13->-r requirements.txt (line 1)) (1.10.1)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.10/dist-packages (from numpyro==0.12.1->-r requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from numpyro==0.12.1->-r requirements.txt (line 3)) (4.66.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from flax==0.6.11->-r requirements.txt (line 4)) (1.0.5)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.10/dist-packages (from flax==0.6.11->-r requirements.txt (line 4)) (0.1.41)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.10/dist-packages (from flax==0.6.11->-r requirements.txt (line 4)) (13.5.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from flax==0.6.11->-r requirements.txt (line 4)) (4.7.1)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from flax==0.6.11->-r requirements.txt (line 4)) (6.0.1)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from optax==0.1.5->-r requirements.txt (line 5)) (1.4.0)
# Requirement already satisfied: chex>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from optax==0.1.5->-r requirements.txt (line 5)) (0.1.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->-r requirements.txt (line 6)) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->-r requirements.txt (line 6)) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->-r requirements.txt (line 6)) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->-r requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->-r requirements.txt (line 6)) (2.0.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.10/dist-packages (from jupyter==1.0.0->-r requirements.txt (line 7)) (6.4.8)
# Collecting qtconsole (from jupyter==1.0.0->-r requirements.txt (line 7))
#   Downloading qtconsole-5.4.3-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.10/dist-packages (from jupyter==1.0.0->-r requirements.txt (line 7)) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from jupyter==1.0.0->-r requirements.txt (line 7)) (6.5.4)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from jupyter==1.0.0->-r requirements.txt (line 7)) (5.5.6)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from jupyter==1.0.0->-r requirements.txt (line 7)) (7.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r requirements.txt (line 8)) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r requirements.txt (line 8)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r requirements.txt (line 8)) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r requirements.txt (line 8)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r requirements.txt (line 8)) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r requirements.txt (line 8)) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r requirements.txt (line 8)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r requirements.txt (line 8)) (2.8.2)
# Requirement already satisfied: etils[epath,epy] in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint==0.2.7->-r requirements.txt (line 9)) (1.4.1)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint==0.2.7->-r requirements.txt (line 9)) (1.5.7)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint==0.2.7->-r requirements.txt (line 9)) (3.20.3)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas==0.13.2->-r requirements.txt (line 10)) (1.9.4.post1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas==0.13.2->-r requirements.txt (line 10)) (1.5.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas==0.13.2->-r requirements.txt (line 10)) (3.6.0)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas==0.13.2->-r requirements.txt (line 10)) (2.0.1)
# Requirement already satisfied: setuptools>=60.0.0 in /usr/local/lib/python3.10/dist-packages (from arviz==0.16.1->-r requirements.txt (line 13)) (67.7.2)
# Requirement already satisfied: xarray>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from arviz==0.16.1->-r requirements.txt (line 13)) (2023.7.0)
# Requirement already satisfied: h5netcdf>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from arviz==0.16.1->-r requirements.txt (line 13)) (1.2.0)
# Requirement already satisfied: xarray-einstats>=0.3 in /usr/local/lib/python3.10/dist-packages (from arviz==0.16.1->-r requirements.txt (line 13)) (0.6.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->-r requirements.txt (line 6)) (3.27.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->-r requirements.txt (line 6)) (16.0.6)
# Requirement already satisfied: dm-tree>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from chex>=0.1.5->optax==0.1.5->-r requirements.txt (line 5)) (0.1.8)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chex>=0.1.5->optax==0.1.5->-r requirements.txt (line 5)) (0.12.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas==0.13.2->-r requirements.txt (line 10)) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas==0.13.2->-r requirements.txt (line 10)) (2023.7.22)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas==0.13.2->-r requirements.txt (line 10)) (8.1.6)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas==0.13.2->-r requirements.txt (line 10)) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas==0.13.2->-r requirements.txt (line 10)) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas==0.13.2->-r requirements.txt (line 10)) (1.16.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from h5netcdf>=1.0.2->arviz==0.16.1->-r requirements.txt (line 13)) (3.9.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas==0.13.2->-r requirements.txt (line 10)) (2023.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax==0.6.11->-r requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1->flax==0.6.11->-r requirements.txt (line 4)) (2.16.1)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[epath,epy]->orbax-checkpoint==0.2.7->-r requirements.txt (line 9)) (6.0.1)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[epath,epy]->orbax-checkpoint==0.2.7->-r requirements.txt (line 9)) (3.16.2)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter==1.0.0->-r requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter==1.0.0->-r requirements.txt (line 7)) (7.34.0)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter==1.0.0->-r requirements.txt (line 7)) (5.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter==1.0.0->-r requirements.txt (line 7)) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter==1.0.0->-r requirements.txt (line 7)) (6.3.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter==1.0.0->-r requirements.txt (line 7)) (3.6.5)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter==1.0.0->-r requirements.txt (line 7)) (3.0.8)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.1->-r requirements.txt (line 6)) (2.1.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-console->jupyter==1.0.0->-r requirements.txt (line 7)) (3.0.39)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 7)) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 7)) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 7)) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 7)) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 7)) (0.4)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 7)) (5.3.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 7)) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 7)) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 7)) (0.8.0)
# Requirement already satisfied: nbformat>=5.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 7)) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 7)) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 7)) (1.2.1)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 7)) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 7)) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 7)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 7)) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 7)) (0.17.1)
# Collecting qtpy>=2.0.1 (from qtconsole->jupyter==1.0.0->-r requirements.txt (line 7))
#   Downloading QtPy-2.3.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.1->-r requirements.txt (line 6)) (1.3.0)
# Collecting jedi>=0.16 (from ipython>=5.0.0->ipykernel->jupyter==1.0.0->-r requirements.txt (line 7))
#   Downloading jedi-0.19.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 84.6 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter==1.0.0->-r requirements.txt (line 7)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter==1.0.0->-r requirements.txt (line 7)) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter==1.0.0->-r requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter==1.0.0->-r requirements.txt (line 7)) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter==1.0.0->-r requirements.txt (line 7)) (4.8.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.7->nbconvert->jupyter==1.0.0->-r requirements.txt (line 7)) (3.10.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax==0.6.11->-r requirements.txt (line 4)) (0.1.2)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.1->nbconvert->jupyter==1.0.0->-r requirements.txt (line 7)) (2.18.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.1->nbconvert->jupyter==1.0.0->-r requirements.txt (line 7)) (4.19.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter==1.0.0->-r requirements.txt (line 7)) (0.2.6)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.10/dist-packages (from terminado>=0.8.3->notebook->jupyter==1.0.0->-r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook->jupyter==1.0.0->-r requirements.txt (line 7)) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->jupyter==1.0.0->-r requirements.txt (line 7)) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->jupyter==1.0.0->-r requirements.txt (line 7)) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->jupyter==1.0.0->-r requirements.txt (line 7)) (0.8.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter==1.0.0->-r requirements.txt (line 7)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter==1.0.0->-r requirements.txt (line 7)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter==1.0.0->-r requirements.txt (line 7)) (0.9.2)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.0.0->-r requirements.txt (line 7)) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter==1.0.0->-r requirements.txt (line 7)) (2.21)
# Building wheels for collected packages: jax
#   Building wheel for jax (pyproject.toml) ... done
#   Created wheel for jax: filename=jax-0.4.13-py3-none-any.whl size=1518704 sha256=e19295c5fe11f75770776c77f977af9c897eb173a07847fca3a7405a6402185f
#   Stored in directory: /root/.cache/pip/wheels/f3/7a/25/f297f69029b5e4064e4736a0c4b3996a44cc27781c120bcb99
# Successfully built jax
# Installing collected packages: qtpy, numpy, jedi, dill, jaxlib, jax, qtconsole, orbax-checkpoint, numpyro, optax, arviz, flax, jupyter
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.4.14+cuda11.cudnn86
#     Uninstalling jaxlib-0.4.14+cuda11.cudnn86:
#       Successfully uninstalled jaxlib-0.4.14+cuda11.cudnn86
#   Attempting uninstall: jax
#     Found existing installation: jax 0.4.14
#     Uninstalling jax-0.4.14:
#       Successfully uninstalled jax-0.4.14
#   Attempting uninstall: orbax-checkpoint
#     Found existing installation: orbax-checkpoint 0.3.2
#     Uninstalling orbax-checkpoint-0.3.2:
#       Successfully uninstalled orbax-checkpoint-0.3.2
#   Attempting uninstall: optax
#     Found existing installation: optax 0.1.7
#     Uninstalling optax-0.1.7:
#       Successfully uninstalled optax-0.1.7
#   Attempting uninstall: arviz
#     Found existing installation: arviz 0.15.1
#     Uninstalling arviz-0.15.1:
#       Successfully uninstalled arviz-0.15.1
#   Attempting uninstall: flax
#     Found existing installation: flax 0.7.2
#     Uninstalling flax-0.7.2:
#       Successfully uninstalled flax-0.7.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.25.1 which is incompatible.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.25.1 which is incompatible.
# Successfully installed arviz-0.16.1 dill-0.3.6 flax-0.6.11 jax-0.4.13 jaxlib-0.4.13 jedi-0.19.0 jupyter-1.0.0 numpy-1.25.1 numpyro-0.12.1 optax-0.1.5 orbax-checkpoint-0.2.7 qtconsole-5.4.3 qtpy-2.3.1

# %%
import random as rnd

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.axes import Axes
from matplotlib.cm import coolwarm
import numpyro
from numpyro.infer import Predictive
from numpyro.diagnostics import hpdi
numpyro.set_host_device_count(4)
import jax
import optax
from jax import random
import jax.numpy as jnp
from flax import linen as nn

from priorCVAE.models import MLPEncoder, MLPDecoder, VAE
from priorCVAE.priors import Matern52
from priorCVAE.datasets import GPDataset
from priorCVAE.trainer import VAETrainer
from priorCVAE.losses import SquaredSumAndKL
from priorCVAE.utility import save_model_params, load_model_params

import jax.config as config
config.update("jax_enable_x64", True)

# %%
iamaway = 0
while (iamaway == 0):
  iamaway = 0
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-bf5e66ea7447> in <cell line: 2>()
#       1 iamaway = 0
# ----> 2 while (iamaway == 0):
#       3   iamaway = 0
#
# KeyboardInterrupt:

# %%
# Configuration dictionary
args = {
        "conditional": False,

        # data
        "x_dim": 2,
        "n_data": 85,

        # architecture
        "input_dim" : 7225,
        "hidden_dim": 500,
        "activation_fn": nn.leaky_relu,
        "latent_dim": 300,

        # VAE training
        "batch_size": 400,
        "num_iterations": 1000,
        "learning_rate": 1e-4,
        "vae_var": 1.,
       }

# %%
kernel = Matern52()

gp_data_generator = GPDataset(n_data=args["n_data"], kernel=kernel, sample_lengthscale=False, x_dim=2)
# Out:
# WARNING:jax._src.xla_bridge:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
sample_x_train, sample_y_train, sample_ls_train = gp_data_generator.simulatedata(n_samples=1000)
x_test, y_test, ls_test = gp_data_generator.simulatedata(n_samples=1000)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, subplot_kw={"projection": "3d"})

x = jnp.linspace(0, 1, args['n_data'])
x1, x2 = jnp.meshgrid(x, x)

ax.plot_surface(x1, x2, y_test.reshape(-1,args['n_data'],args['n_data'])[0], cmap=coolwarm)
ax.set_xlabel('$x1$')
ax.set_ylabel('$x2$')
ax.set_title("Example $f$")
# Out:
# Text(0.5, 0.92, 'Example $f$')

# %%
out_dim = args["input_dim"]
hidden_dim = args["hidden_dim"]
activation_fn = args["activation_fn"]
latent_dim = args["latent_dim"]
batch_size = args["batch_size"]
num_iterations = args["num_iterations"]
learning_rate = args["learning_rate"]
vae_var = args["vae_var"]
encoder = MLPEncoder(hidden_dim, latent_dim, activation_fn)
decoder = MLPDecoder(hidden_dim, out_dim, activation_fn)
model = VAE(encoder, decoder)

optimizer = optax.adam(learning_rate=learning_rate)

# %%
trainer = VAETrainer(model, optimizer, loss=SquaredSumAndKL(vae_var=vae_var))
trainer.init_params(sample_y_train[0])

test_set = (x_test, y_test, ls_test)
loss_vals, test_vals, time_taken = trainer.train(gp_data_generator, test_set, num_iterations)

print(f'Training of {num_iterations} iterations took {round(time_taken)} seconds')
# Out:
# [    1] training loss: 681573.222, test loss: 6004222.717
# [   11] training loss: 397859.706, test loss: 4763798.858
# [   21] training loss: 426978.649, test loss: 4186275.334
# [   31] training loss: 375170.278, test loss: 3725528.448
# [   41] training loss: 333260.599, test loss: 3137710.341
# [   51] training loss: 262043.831, test loss: 2491072.080
# [   61] training loss: 219802.443, test loss: 1971626.673
# [   71] training loss: 162871.503, test loss: 1619784.634
# [   81] training loss: 149975.956, test loss: 1415159.801
# [   91] training loss: 136584.978, test loss: 1303427.468
# [  101] training loss: 128134.898, test loss: 1242907.637
# [  111] training loss: 117473.388, test loss: 1194433.616
# [  121] training loss: 122128.686, test loss: 1154055.606
# [  131] training loss: 118395.555, test loss: 1118221.094
# [  141] training loss: 121139.358, test loss: 1079985.014
# [  151] training loss: 110385.642, test loss: 1038043.937
# [  161] training loss: 102541.834, test loss: 989470.484
# [  171] training loss: 92334.739, test loss: 945989.927
# [  181] training loss: 89756.664, test loss: 899590.998
# [  191] training loss: 86285.494, test loss: 844929.313
# [  201] training loss: 77712.268, test loss: 799508.457
# [  211] training loss: 78378.594, test loss: 769053.635
# [  221] training loss: 75347.554, test loss: 740565.964
# [  231] training loss: 71950.707, test loss: 719642.142
# [  241] training loss: 69606.094, test loss: 698471.703
# [  251] training loss: 67852.319, test loss: 686444.959
# [  261] training loss: 68292.578, test loss: 670538.603
# [  271] training loss: 66833.678, test loss: 663260.243
# [  281] training loss: 66237.848, test loss: 659539.905
# [  291] training loss: 65521.857, test loss: 639633.405
# [  301] training loss: 62471.288, test loss: 624383.600
# [  311] training loss: 61484.281, test loss: 618149.425
# [  321] training loss: 60811.186, test loss: 605636.251
# [  331] training loss: 60560.431, test loss: 603003.813
# [  341] training loss: 58741.554, test loss: 594141.250
# [  351] training loss: 59536.266, test loss: 585957.302
# [  361] training loss: 60427.199, test loss: 580205.127
# [  371] training loss: 57174.492, test loss: 576449.119
# [  381] training loss: 57572.891, test loss: 566907.652
# [  391] training loss: 54934.240, test loss: 572698.430
# [  401] training loss: 57227.436, test loss: 562562.962
# [  411] training loss: 55948.621, test loss: 559615.808
# [  421] training loss: 55306.604, test loss: 574078.380
# [  431] training loss: 58655.754, test loss: 579894.637
# [  441] training loss: 52744.874, test loss: 565783.996
# [  451] training loss: 56709.834, test loss: 538122.736
# [  461] training loss: 54128.891, test loss: 533683.258
# [  471] training loss: 54090.280, test loss: 537605.221
# [  481] training loss: 53175.871, test loss: 531909.510
# [  491] training loss: 50714.214, test loss: 524586.206
# [  501] training loss: 51873.813, test loss: 522918.365
# [  511] training loss: 51566.776, test loss: 513461.978
# [  521] training loss: 50161.331, test loss: 513660.302
# [  531] training loss: 50491.666, test loss: 521303.356
# [  541] training loss: 50301.875, test loss: 507292.136
# [  551] training loss: 50370.226, test loss: 514885.295
# [  561] training loss: 50849.720, test loss: 499498.109
# [  571] training loss: 50794.216, test loss: 509523.488
# [  581] training loss: 48294.090, test loss: 504703.783
# [  591] training loss: 48364.475, test loss: 508617.655
# [  601] training loss: 50593.087, test loss: 492304.766
# [  611] training loss: 51350.639, test loss: 517999.164
# [  621] training loss: 47505.489, test loss: 490260.413
# [  631] training loss: 49233.907, test loss: 480162.456
# [  641] training loss: 47665.565, test loss: 470659.294
# [  651] training loss: 46806.201, test loss: 473015.020
# [  661] training loss: 47262.956, test loss: 463886.082
# [  671] training loss: 47562.232, test loss: 461386.775
# [  681] training loss: 44788.514, test loss: 475365.817
# [  691] training loss: 46415.933, test loss: 491944.314
# [  701] training loss: 44834.045, test loss: 458817.783
# [  711] training loss: 43152.295, test loss: 448274.411
# [  721] training loss: 44993.649, test loss: 444018.448
# [  731] training loss: 44827.926, test loss: 443230.658
# [  741] training loss: 44152.809, test loss: 439092.029
# [  751] training loss: 42156.472, test loss: 434374.430
# [  761] training loss: 43851.986, test loss: 432334.566
# [  771] training loss: 42515.969, test loss: 431350.725
# [  781] training loss: 44861.489, test loss: 423805.095
# [  791] training loss: 45280.472, test loss: 421759.359
# [  801] training loss: 42739.735, test loss: 422556.530
# [  811] training loss: 43000.764, test loss: 422022.856
# [  821] training loss: 42484.288, test loss: 417391.969
# [  831] training loss: 40506.471, test loss: 419421.476
# [  841] training loss: 42885.720, test loss: 411270.628
# [  851] training loss: 42184.657, test loss: 408249.978
# [  861] training loss: 39897.604, test loss: 405217.657
# [  871] training loss: 39300.905, test loss: 403929.133
# [  881] training loss: 39020.500, test loss: 398629.278
# [  891] training loss: 39540.179, test loss: 397747.335
# [  901] training loss: 38468.863, test loss: 395969.446
# [  911] training loss: 40912.004, test loss: 405025.432
# [  921] training loss: 39549.039, test loss: 409391.167
# [  931] training loss: 39104.044, test loss: 390882.862
# [  941] training loss: 41573.671, test loss: 385865.436
# [  951] training loss: 37747.946, test loss: 388146.207
# [  961] training loss: 41998.705, test loss: 380554.387
# [  971] training loss: 38790.571, test loss: 387415.596
# [  981] training loss: 36770.413, test loss: 381423.444
# [  991] training loss: 37638.775, test loss: 375070.114
# [ 1001] training loss: 36588.829, test loss: 374305.698
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-816e7c8e5383> in <cell line: 5>()
#       3
#       4 test_set = (x_test, y_test, ls_test)
# ----> 5 loss_vals, test_vals, time_taken = trainer.train(gp_data_generator, test_set, num_iterations)
#       6
#       7 print(f'Training of {num_iterations} iterations took {round(time_taken)} seconds')
#
# /content/priorCVAE/trainer.py in train(self, data_generator, test_set, num_iterations, batch_size, debug, key)
#     106         for iterations in range(num_iterations):
#     107             # Generate new batch
# --> 108             batch_train = data_generator.simulatedata(batch_size)
#     109             z_key, key = jax.random.split(z_key)
#     110             self.state, loss_train_value = self.train_step(self.state, batch_train, key)
#
# /content/priorCVAE/datasets/gp_dataset.py in simulatedata(self, n_samples)
#      55
#      56         gp_predictive = Predictive(GP, num_samples=n_samples)
# ---> 57         all_draws = gp_predictive(rng_key, x=self.x, kernel=self.kernel, jitter=1e-5,
#      58                                   sample_lengthscale=self.sample_lengthscale)
#      59
#
# /usr/local/lib/python3.10/dist-packages/numpyro/infer/util.py in __call__(self, rng_key, *args, **kwargs)
#    1005         """
#    1006         if self.batch_ndims == 0 or self.params == {} or self.guide is None:
# -> 1007             return self._call_with_params(rng_key, self.params, args, kwargs)
#    1008         elif self.batch_ndims == 1:  # batch over parameters
#    1009             batch_size = jnp.shape(tree_flatten(self.params)[0][0])[0]
#
# /usr/local/lib/python3.10/dist-packages/numpyro/infer/util.py in _call_with_params(self, rng_key, params, args, kwargs)
#     982             )
#     983         model = substitute(self.model, self.params)
# --> 984         return _predictive(
#     985             rng_key,
#     986             model,
#
# /usr/local/lib/python3.10/dist-packages/numpyro/infer/util.py in _predictive(rng_key, model, posterior_samples, batch_shape, return_sites, infer_discrete, parallel, model_args, model_kwargs)
#     819     rng_key = rng_key.reshape((*batch_shape, 2))
#     820     chunk_size = num_samples if parallel else 1
# --> 821     return soft_vmap(
#     822         single_prediction, (rng_key, posterior_samples), len(batch_shape), chunk_size
#     823     )
#
# /usr/local/lib/python3.10/dist-packages/numpyro/util.py in soft_vmap(fn, xs, batch_ndims, chunk_size)
#     408         fn = vmap(fn)
#     409
# --> 410     ys = lax.map(fn, xs) if num_chunks > 1 else fn(xs)
#     411     map_ndims = int(num_chunks > 1) + int(chunk_size > 1)
#     412     ys = tree_map(
#
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/lax/control_flow/loops.py in map(f, xs)
#    1816   """
#    1817   g = lambda _, x: ((), f(x))
# -> 1818   _, ys = scan(g, (), xs)
#    1819   return ys
#    1820
#
#     [... skipping hidden 1 frame]
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/lax/control_flow/loops.py in scan(f, init, xs, length, reverse, unroll)
#     261         f'Effects not supported in `scan`: {disallowed_effects}')
#     262
# --> 263   out = scan_p.bind(*consts, *in_flat,
#     264                     reverse=reverse, length=length, jaxpr=jaxpr,
#     265                     num_consts=len(consts), num_carry=len(init_flat),
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/lax/control_flow/loops.py in scan_bind(*args, **params)
#    1036     _scan_typecheck(True, *in_atoms, **params)
#    1037     core.check_jaxpr(params['jaxpr'].jaxpr)
# -> 1038   return core.AxisPrimitive.bind(scan_p, *args, **params)
#    1039
#    1040 scan_p = core.AxisPrimitive("scan")
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py in bind(self, *args, **params)
#    2675     top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2676                  else axis_main.with_cur_sublevel())
# -> 2677     return self.bind_with_trace(top_trace, args, params)
#    2678
#    2679
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py in bind_with_trace(self, trace, args, params)
#     381
#     382   def bind_with_trace(self, trace, args, params):
# --> 383     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     384     return map(full_lower, out) if self.multiple_results else full_lower(out)
#     385
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/core.py in process_primitive(self, primitive, tracers, params)
#     813
#     814   def process_primitive(self, primitive, tracers, params):
# --> 815     return primitive.impl(*tracers, **params)
#     816
#     817   def process_call(self, primitive, f, tracers, params):
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/dispatch.py in apply_primitive(prim, *args, **params)
#     142     raise ValueError(msg) from None
#     143
# --> 144   return compiled_fun(*args)
#     145
#     146
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/profiler.py in wrapper(*args, **kwargs)
#     312   def wrapper(*args, **kwargs):
#     313     with TraceAnnotation(name, **decorator_kwargs):
# --> 314       return func(*args, **kwargs)
#     315     return wrapper
#     316   return wrapper
#
# /usr/local/lib/python3.10/dist-packages/jax/_src/interpreters/pxla.py in __call__(self, *args)
#    1347           results.consume_token())
#    1348     else:
# -> 1349       results = self.xla_executable.execute_sharded(input_bufs)
#    1350     if dispatch.needs_check_special():
#    1351       out_arrays = results.disassemble_into_single_device_arrays()
#
# KeyboardInterrupt:

# %%
import pickle

# %%
t = trainer.state.params

# %%
with open('decoder_result', 'wb') as f:
    pickle.dump(t, f)

# %%
decoder_params = trainer.state.params['decoder']

# %%
decoder_params
# Out:
# FrozenDict({
#     dec_hidden_0: {
#         bias: Array([-0.02277956, -0.01264745, -0.01490578, -0.02313827, -0.02686583,
#                -0.02899592, -0.01614581, -0.01845904, -0.03108257, -0.02308119,
#                -0.02281932, -0.02887928, -0.02679524, -0.03662075, -0.01257071,
#                -0.02191011, -0.01780502, -0.02268064, -0.0353014 , -0.03755578,
#                -0.01255094, -0.01847768, -0.03044567, -0.03436576, -0.00606211,
#                -0.01623766, -0.03143846, -0.01471159, -0.02278494, -0.01127901,
#                -0.03064558, -0.02740729, -0.03445163, -0.0269537 , -0.02466028,
#                -0.02170145, -0.01545402, -0.01834957, -0.0293164 , -0.03091777,
#                -0.01588858, -0.01055918, -0.01798692, -0.01348072, -0.02476532,
#                -0.03228308, -0.02549574, -0.02883647, -0.02013163, -0.01895406,
#                -0.03255066, -0.01673238, -0.01958832, -0.01317856, -0.03022795,
#                -0.01659348, -0.01331531, -0.0341768 , -0.03281717, -0.0120132 ,
#                -0.02183765, -0.0246285 , -0.01476864, -0.00809186, -0.018488  ,
#                -0.02268958, -0.01589335, -0.03193283, -0.03550763, -0.0208472 ,
#                -0.01991185, -0.02274914, -0.00918934, -0.02128846, -0.0294482 ,
#                -0.03352598, -0.03245141, -0.02868652, -0.0308165 , -0.01869722,
#                -0.03375045, -0.02150542, -0.02940913, -0.02264147, -0.02633922,
#                -0.02200195, -0.02828289, -0.02764484, -0.01986222, -0.01990232,
#                -0.03147688, -0.01957665, -0.02340776, -0.01337034, -0.02881614,
#                 0.00206277, -0.03013667, -0.02994934, -0.00630988, -0.01393755,
#                -0.01990823, -0.02033214, -0.03382571, -0.0227707 , -0.02086362,
#                -0.03667152, -0.03334813, -0.01515185, -0.02770139, -0.0169226 ,
#                -0.03030114, -0.03024834, -0.01639484, -0.01873972, -0.01631774,
#                -0.02113557, -0.01847033,  0.00182462, -0.01933   , -0.024299  ,
#                -0.02543731, -0.03650773, -0.01899485, -0.03089067, -0.0315922 ,
#                -0.0158059 , -0.02410136, -0.02792067, -0.01995847,  0.00547666,
#                -0.01760572, -0.01822484, -0.02213283, -0.0157298 , -0.03023007,
#                -0.01866771, -0.02340122, -0.02333909, -0.02326016, -0.03151578,
#                -0.03435922, -0.02665635, -0.02690371, -0.03321033, -0.02696881,
#                -0.02882358, -0.00663477, -0.02797518, -0.01999439, -0.02107518,
#                -0.01647234, -0.02172573, -0.01557783, -0.01658683, -0.02930224,
#                -0.02016734, -0.03279477, -0.03720013, -0.02530134, -0.00994484,
#                -0.01636175, -0.02378516, -0.0299871 , -0.03414829, -0.02302989,
#                -0.01794913, -0.02031587, -0.01840057, -0.01592263, -0.00828173,
#                -0.02803899, -0.02307943, -0.02505527, -0.03523939, -0.02766695,
#                -0.01883973, -0.03138206, -0.01544949, -0.02131736, -0.0168348 ,
#                -0.01379548, -0.01510204, -0.02788422, -0.02658534, -0.0266745 ,
#                -0.00821668, -0.01855631, -0.0265465 , -0.010217  , -0.02974338,
#                -0.0154547 , -0.01615818, -0.00352988, -0.02264092, -0.02015957,
#                -0.03790652, -0.02660481, -0.02166763, -0.03363407, -0.02959426,
#                -0.02573123, -0.01140062, -0.01892374, -0.02904177, -0.02629827,
#                -0.03601521, -0.02191931, -0.01633154, -0.02611517, -0.02239913,
#                -0.03156113, -0.015922  , -0.01694231, -0.02508004, -0.03301289,
#                -0.02295907, -0.02028363, -0.01559395, -0.01627491, -0.0179362 ,
#                -0.02955054, -0.03028909, -0.02207862, -0.03130222, -0.00685518,
#                -0.01687966, -0.03015137, -0.01999828, -0.02137104, -0.02685273,
#                -0.02299559, -0.03066579, -0.02184403, -0.02687806, -0.02858383,
#                -0.03058309, -0.0310639 , -0.01741549, -0.02669245, -0.02484843,
#                -0.00830002, -0.03592116, -0.02300445, -0.02773833, -0.03139008,
#                 0.002266  , -0.02762727, -0.02907656, -0.01960696, -0.01424557,
#                -0.02833674, -0.01148275, -0.03800631, -0.03216185, -0.01394497,
#                -0.02346219, -0.01938885, -0.01238728, -0.02044355, -0.02592742,
#                -0.02747672, -0.02717816, -0.01572084, -0.02335965, -0.03852994,
#                -0.02719374, -0.01410922, -0.03474363, -0.02714554, -0.01193644,
#                -0.00384306, -0.0123965 , -0.01993399, -0.02935357, -0.03327877,
#                -0.01157288, -0.0206556 , -0.01028494, -0.02166042, -0.01230128,
#                -0.01384425, -0.01928977, -0.03494591, -0.02593027, -0.02531213,
#                -0.01531449, -0.00942694, -0.02970697, -0.03355031, -0.01982155,
#                -0.02322602, -0.0316379 , -0.00950015, -0.01063482, -0.01806956,
#                -0.02628074, -0.02970023, -0.02120805, -0.0213907 , -0.01718009,
#                -0.0150084 , -0.03371326, -0.01914154, -0.02045629, -0.0096522 ,
#                -0.02794364, -0.02425898, -0.01173437, -0.02275046, -0.01647717,
#                -0.02548476, -0.02528819, -0.02941576, -0.0059196 , -0.01806912,
#                -0.00846496, -0.03278016, -0.02943052, -0.01553365, -0.03373227,
#                -0.02874555, -0.01132311, -0.02752651, -0.02065879, -0.02781586,
#                -0.02442177, -0.02897422, -0.01636383, -0.02527112, -0.01960629,
#                -0.02809584, -0.02247922, -0.00868923, -0.02047028, -0.02947503,
#                -0.02796623, -0.03338141, -0.0260182 , -0.01560721, -0.01825789,
#                -0.02074585, -0.01919446, -0.02453353, -0.03296387, -0.02540964,
#                -0.02864901, -0.03895883, -0.00939604, -0.01555366, -0.02572234,
#                -0.03005507, -0.0206129 , -0.01772006, -0.02832398, -0.02918424,
#                -0.02770216, -0.02753568, -0.01699265, -0.02465655, -0.02172608,
#                -0.0155196 , -0.03010788, -0.03001895, -0.01117532, -0.0289166 ,
#                -0.02615557, -0.0278683 , -0.03158218, -0.01719551, -0.01558323,
#                -0.01622271, -0.01593586, -0.01709937, -0.02189858, -0.0177343 ,
#                -0.01648866, -0.03361764, -0.02760207, -0.02822155, -0.02128876,
#                -0.0210712 , -0.0320543 , -0.00917515, -0.0118041 , -0.01525887,
#                -0.00714218, -0.02066293, -0.00848243, -0.03144077, -0.026627  ,
#                -0.01350707, -0.02678572, -0.02502398, -0.02348289, -0.0276584 ,
#                -0.01953286, -0.01133656, -0.03136278, -0.02867714, -0.02609252,
#                -0.0259307 , -0.01705766, -0.02397168, -0.01497443, -0.01295095,
#                -0.01275874, -0.01297281, -0.03080607, -0.02718494, -0.02783898,
#                -0.0237636 , -0.01735441, -0.03323803, -0.02137278, -0.01718543,
#                -0.02974795, -0.01872169, -0.02373577, -0.02739604, -0.02990565,
#                -0.03112656, -0.03490002, -0.01300136, -0.01999845, -0.01756039,
#                -0.02410649, -0.01710922, -0.0116494 , -0.02381976, -0.03164909,
#                -0.02536978, -0.02923104, -0.01600233, -0.02040259, -0.01865606,
#                -0.00949673, -0.01176841, -0.02567997, -0.01568312, -0.0197752 ,
#                -0.01565259, -0.01039707, -0.0233924 , -0.03077013, -0.02752221,
#                -0.02509143, -0.03247053, -0.03120693, -0.02879813, -0.02246879,
#                -0.02425607, -0.02096119, -0.01623265, -0.02599634, -0.0030993 ,
#                -0.00388746, -0.01703745, -0.01013198, -0.00224742, -0.02361126,
#                 0.00298536, -0.01686518, -0.03293356, -0.03152098, -0.02975363,
#                -0.01466283, -0.02994374, -0.01468912, -0.01278226, -0.02011284,
#                -0.01410617, -0.03294865, -0.02967712, -0.03189304, -0.03361931,
#                -0.02749387, -0.02379484, -0.02404241, -0.02879515, -0.03147196,
#                -0.02481409, -0.03188428, -0.01931435, -0.03707414, -0.02861007,
#                -0.02984907,  0.00850953, -0.02914751, -0.02143544, -0.00675426,
#                -0.02459335, -0.03424755, -0.01696828, -0.03699365, -0.02131294,
#                -0.01144341, -0.01717779, -0.01523115, -0.02969801, -0.01569502],      dtype=float32),
#         kernel: Array([[ 0.01924189, -0.05211358, -0.01607504, ...,  0.05819697,
#                 -0.00975836,  0.01139881],
#                [ 0.01650513,  0.00308104, -0.04743163, ...,  0.03177156,
#                  0.00816643,  0.02585311],
#                [-0.07076953, -0.0188399 ,  0.00249987, ...,  0.01232444,
#                 -0.07848676,  0.01242877],
#                ...,
#                [-0.03054139, -0.02043986, -0.04114805, ..., -0.05778264,
#                  0.04522095,  0.02785732],
#                [ 0.01580778, -0.01451244,  0.04371183, ...,  0.03117925,
#                 -0.04973674, -0.04191112],
#                [ 0.00509515, -0.0400337 , -0.01532167, ...,  0.05504841,
#                 -0.03630254, -0.05148983]], dtype=float32),
#     },
#     dec_out: {
#         bias: Array([-0.00505958, -0.00685736, -0.00186697, ...,  0.01140797,
#                 0.00017692,  0.00310131], dtype=float32),
#         kernel: Array([[ 0.01102554,  0.02651221, -0.05163211, ...,  0.03827496,
#                 -0.01523731,  0.05460488],
#                [-0.05814806, -0.00569904, -0.05737867, ...,  0.11200929,
#                  0.06285156,  0.04824985],
#                [ 0.01455128, -0.08446085,  0.01564378, ..., -0.07992448,
#                  0.00442365, -0.06536952],
#                ...,
#                [ 0.02217288, -0.02915484, -0.07551377, ...,  0.02944047,
#                 -0.04779295,  0.01573161],
#                [-0.01290844, -0.08979096, -0.00130709, ..., -0.01708904,
#                 -0.01358483, -0.03789815],
#                [ 0.06074265, -0.06311859,  0.00423286, ...,  0.06169222,
#                 -0.00296674,  0.03161691]], dtype=float32),
#     },
# })

# %%
decoder_params = trainer.state.params['decoder']

key = jax.random.PRNGKey(rnd.randint(0, 9999))
rng, z_rng, init_rng = random.split(key, 3)
z = random.normal(z_rng, (batch_size, latent_dim))

decoder = MLPDecoder(hidden_dim, out_dim, activation_fn)
out = decoder.apply({'params': decoder_params}, z)

x = jnp.linspace(0, 1, args['n_data'])
x1, x2 = jnp.meshgrid(x, x)

fig, ax = plt.subplots(nrows=1, ncols=1, subplot_kw={"projection": "3d"})
ax.plot_surface(x1, x2, y_test.reshape(-1,args['n_data'],args['n_data'])[0], cmap=coolwarm)
ax.set_xlabel('$x1$')
ax.set_ylabel('$x2$')
ax.set_zlabel('$f_{VAE}(x)$')
ax.set_title("Example of learnt realization")
ax.set_box_aspect(aspect=None, zoom=0.8)
plt.show()
